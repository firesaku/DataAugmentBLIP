# %%
pip install evaluate
# Out:
# Requirement already satisfied: evaluate in d:\conda\lib\site-packages (0.4.3)
# Requirement already satisfied: datasets>=2.0.0 in d:\conda\lib\site-packages (from evaluate) (3.5.0)
# Requirement already satisfied: numpy>=1.17 in d:\conda\lib\site-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in d:\conda\lib\site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in d:\conda\lib\site-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in d:\conda\lib\site-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in d:\conda\lib\site-packages (from evaluate) (4.66.5)
# Requirement already satisfied: xxhash in c:\users\admin\appdata\roaming\python\python312\site-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in c:\users\admin\appdata\roaming\python\python312\site-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in d:\conda\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.6.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in d:\conda\lib\site-packages (from evaluate) (0.30.2)
# Requirement already satisfied: packaging in d:\conda\lib\site-packages (from evaluate) (24.1)
# Requirement already satisfied: filelock in d:\conda\lib\site-packages (from datasets>=2.0.0->evaluate) (3.13.1)
# Requirement already satisfied: pyarrow>=15.0.0 in d:\conda\lib\site-packages (from datasets>=2.0.0->evaluate) (16.1.0)
# Requirement already satisfied: aiohttp in d:\conda\lib\site-packages (from datasets>=2.0.0->evaluate) (3.10.5)
# Requirement already satisfied: pyyaml>=5.1 in d:\conda\lib\site-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\conda\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\conda\lib\site-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\conda\lib\site-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\conda\lib\site-packages (from requests>=2.19.0->evaluate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\conda\lib\site-packages (from requests>=2.19.0->evaluate) (2025.1.31)
# Requirement already satisfied: colorama in d:\conda\lib\site-packages (from tqdm>=4.62.1->evaluate) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\conda\lib\site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\conda\lib\site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\conda\lib\site-packages (from pandas->evaluate) (2023.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\conda\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\conda\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\conda\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\conda\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\conda\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\conda\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.11.0)
# Requirement already satisfied: six>=1.5 in d:\conda\lib\site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install open_clip_torch==2.23.0 transformers==4.35.2 datasets tqdm evaluate
# Out:
# Collecting open_clip_torch==2.23.0
#   Downloading open_clip_torch-2.23.0-py3-none-any.whl.metadata (30 kB)
# Collecting transformers==4.35.2
#   Downloading transformers-4.35.2-py3-none-any.whl.metadata (123 kB)
# Requirement already satisfied: datasets in d:\conda\lib\site-packages (3.2.0)
# Requirement already satisfied: tqdm in d:\conda\lib\site-packages (4.66.5)
# Requirement already satisfied: evaluate in d:\conda\lib\site-packages (0.4.3)
# Requirement already satisfied: torch>=1.9.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from open_clip_torch==2.23.0) (2.6.0+cu124)
# Requirement already satisfied: torchvision in c:\users\admin\appdata\roaming\python\python312\site-packages (from open_clip_torch==2.23.0) (0.21.0+cu124)
# Requirement already satisfied: regex in d:\conda\lib\site-packages (from open_clip_torch==2.23.0) (2024.9.11)
# Collecting ftfy (from open_clip_torch==2.23.0)
#   Using cached ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: huggingface-hub in d:\conda\lib\site-packages (from open_clip_torch==2.23.0) (0.30.2)
# Requirement already satisfied: sentencepiece in d:\conda\lib\site-packages (from open_clip_torch==2.23.0) (0.2.0)
# Requirement already satisfied: protobuf in d:\conda\lib\site-packages (from open_clip_torch==2.23.0) (4.25.3)
# Collecting timm (from open_clip_torch==2.23.0)
#   Downloading timm-1.0.15-py3-none-any.whl.metadata (52 kB)
# Requirement already satisfied: filelock in d:\conda\lib\site-packages (from transformers==4.35.2) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in d:\conda\lib\site-packages (from transformers==4.35.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in d:\conda\lib\site-packages (from transformers==4.35.2) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in d:\conda\lib\site-packages (from transformers==4.35.2) (6.0.1)
# Requirement already satisfied: requests in d:\conda\lib\site-packages (from transformers==4.35.2) (2.32.3)
# Collecting tokenizers<0.19,>=0.14 (from transformers==4.35.2)
#   Downloading tokenizers-0.15.2-cp312-none-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\admin\appdata\roaming\python\python312\site-packages (from transformers==4.35.2) (0.5.2)
# Requirement already satisfied: pyarrow>=15.0.0 in d:\conda\lib\site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in d:\conda\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in d:\conda\lib\site-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in c:\users\admin\appdata\roaming\python\python312\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\admin\appdata\roaming\python\python312\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in d:\conda\lib\site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in d:\conda\lib\site-packages (from datasets) (3.10.5)
# Requirement already satisfied: colorama in d:\conda\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\conda\lib\site-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\conda\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\conda\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\conda\lib\site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\conda\lib\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\conda\lib\site-packages (from aiohttp->datasets) (1.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\conda\lib\site-packages (from huggingface-hub->open_clip_torch==2.23.0) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\conda\lib\site-packages (from requests->transformers==4.35.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\conda\lib\site-packages (from requests->transformers==4.35.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\conda\lib\site-packages (from requests->transformers==4.35.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\conda\lib\site-packages (from requests->transformers==4.35.2) (2025.1.31)
# Requirement already satisfied: networkx in d:\conda\lib\site-packages (from torch>=1.9.0->open_clip_torch==2.23.0) (3.3)
# Requirement already satisfied: jinja2 in d:\conda\lib\site-packages (from torch>=1.9.0->open_clip_torch==2.23.0) (3.1.4)
# Requirement already satisfied: setuptools in d:\conda\lib\site-packages (from torch>=1.9.0->open_clip_torch==2.23.0) (69.5.1)
# Requirement already satisfied: sympy==1.13.1 in c:\users\admin\appdata\roaming\python\python312\site-packages (from torch>=1.9.0->open_clip_torch==2.23.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\conda\lib\site-packages (from sympy==1.13.1->torch>=1.9.0->open_clip_torch==2.23.0) (1.3.0)
# Requirement already satisfied: wcwidth in d:\conda\lib\site-packages (from ftfy->open_clip_torch==2.23.0) (0.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\conda\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\conda\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\conda\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in d:\conda\lib\site-packages (from torchvision->open_clip_torch==2.23.0) (10.4.0)
# Requirement already satisfied: six>=1.5 in d:\conda\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\conda\lib\site-packages (from jinja2->torch>=1.9.0->open_clip_torch==2.23.0) (2.1.3)
# Downloading open_clip_torch-2.23.0-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------- ----------- 1.0/1.5 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 3.9 MB/s eta 0:00:00
# Downloading transformers-4.35.2-py3-none-any.whl (7.9 MB)
#    ---------------------------------------- 0.0/7.9 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/7.9 MB 5.0 MB/s eta 0:00:02
#    ------------- -------------------------- 2.6/7.9 MB 6.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/7.9 MB 7.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.8/7.9 MB 6.9 MB/s eta 0:00:01
#    ------------------------------------- -- 7.3/7.9 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.9/7.9 MB 7.0 MB/s eta 0:00:00
# Downloading tokenizers-0.15.2-cp312-none-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.2 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 5.6 MB/s eta 0:00:00
# Using cached ftfy-6.3.1-py3-none-any.whl (44 kB)
# Downloading timm-1.0.15-py3-none-any.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.4 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 6.4 MB/s eta 0:00:00
# Installing collected packages: ftfy, tokenizers, transformers, timm, open_clip_torch
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.0
#     Uninstalling tokenizers-0.21.0:
#       Successfully uninstalled tokenizers-0.21.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.48.3
#     Uninstalling transformers-4.48.3:
#       Successfully uninstalled transformers-4.48.3
# Successfully installed ftfy-6.3.1 open_clip_torch-2.23.0 timm-1.0.15 tokenizers-0.15.2 transformers-4.35.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llava-med 1.5.0 requires backoff, which is not installed.
# llava-med 1.5.0 requires fastapi, which is not installed.
# llava-med 1.5.0 requires gradio==3.35.2, which is not installed.
# llava-med 1.5.0 requires gradio_client==0.2.9, which is not installed.
# llava-med 1.5.0 requires markdown2[all], which is not installed.
# llava-med 1.5.0 requires openai==1.12.0, which is not installed.
# llava-med 1.5.0 requires shortuuid, which is not installed.
# llava-med 1.5.0 requires tiktoken, which is not installed.
# llava-med 1.5.0 requires uvicorn, which is not installed.
# llava-med 1.5.0 requires accelerate==0.21.0, but you have accelerate 1.3.0 which is incompatible.
# llava-med 1.5.0 requires bitsandbytes==0.41.0, but you have bitsandbytes 0.45.3 which is incompatible.
# llava-med 1.5.0 requires einops==0.6.1, but you have einops 0.8.1 which is incompatible.
# llava-med 1.5.0 requires httpx==0.24.0, but you have httpx 0.27.0 which is incompatible.
# llava-med 1.5.0 requires peft==0.4.0, but you have peft 0.14.0 which is incompatible.
# llava-med 1.5.0 requires pydantic<2,>=1, but you have pydantic 2.8.2 which is incompatible.
# llava-med 1.5.0 requires scikit-learn==1.2.2, but you have scikit-learn 1.5.1 which is incompatible.
# llava-med 1.5.0 requires sentencepiece==0.1.99, but you have sentencepiece 0.2.0 which is incompatible.
# llava-med 1.5.0 requires timm==0.9.12, but you have timm 1.0.15 which is incompatible.
# llava-med 1.5.0 requires transformers==4.36.2, but you have transformers 4.35.2 which is incompatible.

# %%
import torch
from open_clip import create_model_from_pretrained, get_tokenizer
from PIL import Image
from datasets import load_dataset
import tqdm
import evaluate


model, preprocess = create_model_from_pretrained(
    "hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224"
)
tokenizer = get_tokenizer("hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224")

device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
model.eval()

dataset = load_dataset("mdwiratathya/SLAKE-vqa-english")
eval_split = dataset["validation"]


all_answers = list({ s["answer"] for s in eval_split })



ans_ids = tokenizer(all_answers).to(device)  # [N, L]
pad_id = tokenizer.tokenizer.pad_token_id
ans_mask = ans_ids.ne(pad_id)

with torch.no_grad():
    answer_feats = model.encode_text(ans_ids)
    answer_feats = answer_feats / answer_feats.norm(dim=-1, keepdim=True)


bleu_metric = evaluate.load("bleu")
rouge_metric = evaluate.load("rouge")
predictions, references = [], []
exact_match = 0

for sample in tqdm.tqdm(eval_split):
    img = sample["image"]
    ref = sample["answer"]

    img_in = preprocess(img).unsqueeze(0).to(device)
    with torch.no_grad():
        img_feat = model.encode_image(img_in)
        img_feat = img_feat / img_feat.norm(dim=-1, keepdim=True)

    scale = model.logit_scale.exp()
    logits = img_feat @ answer_feats.T * scale
    idx = logits.argmax(-1).item()
    pred = all_answers[idx]
    
    predictions.append(pred)
    references.append(ref)
    if pred.lower() == ref.lower():
        exact_match += 1

accuracy = exact_match / len(eval_split)
bleu = bleu_metric.compute(predictions=predictions, references=references)
rouge = rouge_metric.compute(predictions=predictions, references=references)

print("=== BioMedCLIP Zero-Shot Retrieval VQA on SLAKE ===")
print(f"Exact Match Accuracy: {accuracy:.4f}")
print("BLEU:", bleu)
print("ROUGE:", rouge)
# Out:
# D:\Conda\Lib\site-packages\transformers\utils\generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# D:\Conda\Lib\site-packages\transformers\utils\generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# D:\Conda\Lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# D:\Conda\Lib\site-packages\transformers\utils\generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# D:\Conda\Lib\site-packages\huggingface_hub\file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████| 1053/1053 [00:10<00:00, 103.32it/s]
# === BioMedCLIP Zero-Shot Retrieval VQA on SLAKE ===
# Exact Match Accuracy: 0.0313
# BLEU: {'bleu': 0.030762266226803628, 'precisions': [0.06602336211274759, 0.025109170305676855, 0.02147239263803681, 0.025157232704402517], 'brevity_penalty': 1.0, 'length_ratio': 1.2290886392009988, 'translation_length': 1969, 'reference_length': 1602}
# ROUGE: {'rouge1': 0.0654685875483596, 'rouge2': 0.0143265513635884, 'rougeL': 0.06511725585799656, 'rougeLsum': 0.06543237283978023}
